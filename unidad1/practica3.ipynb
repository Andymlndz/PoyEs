# %% [markdown]
# <a href="https://colab.research.google.com/github/Andymlndz/PoyEs/blob/main/unidad1/practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image](https://github.com/JoseGabriel-ITD/Probabilidad-y-Estadistica/blob/main/Cintilla2004.png?raw=true)
#
# # **Probabilidad y estadistica**
#
# ## Unidad 1
#
# ### Practica 3
#
# ### Facilitador: *Dr. José Gabriel Rodríguez Rivas*
#
# ### Alumno: Itzel Andrea Melendez Arrieta

# %%
# basado en el LIBRO estadística para administración pagina 12
# creamos una lista vacía que representa la edad de 100 personas
import random
edades = []
# Hacemos un ciclo para generar 100 numeros aleatorios que representan la edad de las personas
for i in range(100):
    # generamos un numero aleatorio con la funcion randint y lo guardamos en la variable numero_aleatorio
    numero_aleatorio = random.randint(18, 70)
    # Agregamos el numero aleatorio a la lista de valores
    edades.append(numero_aleatorio)
print(edades)
# Out:
# [65, 48, 47, 43, 62, 31, 54, 52, 57, 29, 50, 36, 27, 46, 26, 63, 55, 46, 26, 70, 21, 44, 18, 44, 23, 33, 56, 70, 36, 37, 33, 27, 34, 44, 62, 32, 21, 29, 67, 38, 25, 30, 50, 42, 59, 41, 40, 37, 59, 48, 39, 47, 69, 51, 38, 31, 68, 51, 28, 49, 51, 57, 39, 63, 37, 54, 49, 41, 65, 20, 43, 29, 25, 45, 70, 51, 28, 58, 47, 69, 32, 28, 24, 30, 38, 29, 47, 40, 61, 45, 67, 42, 56, 49, 65, 68, 58, 32, 30, 47]

# %%
import pandas as pd

# Crear un DataFrame de pandas con los números aleatorios
df = pd.DataFrame(edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    65
# 1    48
# 2    47
# 3    43
# 4    62

# %%
# Calcular la tabla de distribución de frecuencias
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')

# Imprimir la tabla de distribución de frecuencias
print("Tabla de Distribución de Frecuencias:")
tabla_frecuencias
# Out:
# Tabla de Distribución de Frecuencias:
#     Edad  Frecuencia
# 40    18           1
# 43    20           1
# 27    21           2
# 41    23           1
# 44    24           1
# 24    25           2
# 29    26           2
# 17    27           2
# 11    28           3
# 1     29           4
# 7     30           3
# 21    31           2
# 5     32           3
# 25    33           2
# 42    34           1
# 16    36           2
# 6     37           3
# 9     38           3
# 31    39           2
# 35    40           2
# 34    41           2
# 37    42           2
# 22    43           2
# 10    44           3
# 33    45           2
# 15    46           2
# 0     47           5
# 13    48           2
# 8     49           3
# 18    50           2
# 2     51           4
# 38    52           1
# 20    54           2
# 39    55           1
# 23    56           2
# 19    57           2
# 30    58           2
# 36    59           2
# 45    61           1
# 12    62           2
# 28    63           2
# 3     65           3
# 26    67           2
# 32    68           2
# 14    69           2
# 4     70           3

# %%
tabla_frecuencias["Frecuencia Relativa"] = tabla_frecuencias["Frecuencia"] / 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frecuencia Relativa
# 40    18           1                 0.01
# 43    20           1                 0.01
# 27    21           2                 0.02
# 41    23           1                 0.01
# 44    24           1                 0.01
# 24    25           2                 0.02
# 29    26           2                 0.02
# 17    27           2                 0.02
# 11    28           3                 0.03
# 1     29           4                 0.04
# 7     30           3                 0.03
# 21    31           2                 0.02
# 5     32           3                 0.03
# 25    33           2                 0.02
# 42    34           1                 0.01
# 16    36           2                 0.02
# 6     37           3                 0.03
# 9     38           3                 0.03
# 31    39           2                 0.02
# 35    40           2                 0.02
# 34    41           2                 0.02
# 37    42           2                 0.02
# 22    43           2                 0.02
# 10    44           3                 0.03
# 33    45           2                 0.02
# 15    46           2                 0.02
# 0     47           5                 0.05
# 13    48           2                 0.02
# 8     49           3                 0.03
# 18    50           2                 0.02
# 2     51           4                 0.04
# 38    52           1                 0.01
# 20    54           2                 0.02
# 39    55           1                 0.01
# 23    56           2                 0.02
# 19    57           2                 0.02
# 30    58           2                 0.02
# 36    59           2                 0.02
# 45    61           1                 0.01
# 12    62           2                 0.02
# 28    63           2                 0.02
# 3     65           3                 0.03
# 26    67           2                 0.02
# 32    68           2                 0.02
# 14    69           2                 0.02
# 4     70           3                 0.03

# %%
tabla_frecuencias["Fre Porcentaje"] = tabla_frecuencias["Frecuencia"] / 100 * 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frecuencia Relativa  Fre Porcentaje
# 40    18           1                 0.01             1.0
# 43    20           1                 0.01             1.0
# 27    21           2                 0.02             2.0
# 41    23           1                 0.01             1.0
# 44    24           1                 0.01             1.0
# 24    25           2                 0.02             2.0
# 29    26           2                 0.02             2.0
# 17    27           2                 0.02             2.0
# 11    28           3                 0.03             3.0
# 1     29           4                 0.04             4.0
# 7     30           3                 0.03             3.0
# 21    31           2                 0.02             2.0
# 5     32           3                 0.03             3.0
# 25    33           2                 0.02             2.0
# 42    34           1                 0.01             1.0
# 16    36           2                 0.02             2.0
# 6     37           3                 0.03             3.0
# 9     38           3                 0.03             3.0
# 31    39           2                 0.02             2.0
# 35    40           2                 0.02             2.0
# 34    41           2                 0.02             2.0
# 37    42           2                 0.02             2.0
# 22    43           2                 0.02             2.0
# 10    44           3                 0.03             3.0
# 33    45           2                 0.02             2.0
# 15    46           2                 0.02             2.0
# 0     47           5                 0.05             5.0
# 13    48           2                 0.02             2.0
# 8     49           3                 0.03             3.0
# 18    50           2                 0.02             2.0
# 2     51           4                 0.04             4.0
# 38    52           1                 0.01             1.0
# 20    54           2                 0.02             2.0
# 39    55           1                 0.01             1.0
# 23    56           2                 0.02             2.0
# 19    57           2                 0.02             2.0
# 30    58           2                 0.02             2.0
# 36    59           2                 0.02             2.0
# 45    61           1                 0.01             1.0
# 12    62           2                 0.02             2.0
# 28    63           2                 0.02             2.0
# 3     65           3                 0.03             3.0
# 26    67           2                 0.02             2.0
# 32    68           2                 0.02             2.0
# 14    69           2                 0.02             2.0
# 4     70           3                 0.03             3.0

# %%
tabla_frecuencias["Frecuencia Acumulada"] = tabla_frecuencias["Frecuencia"].cumsum()

# %%
# Importamos la librería math de funciones matemáticas
import math
# Volvemos a usar la lista edades
print(edades)
# Out:
# [65, 48, 47, 43, 62, 31, 54, 52, 57, 29, 50, 36, 27, 46, 26, 63, 55, 46, 26, 70, 21, 44, 18, 44, 23, 33, 56, 70, 36, 37, 33, 27, 34, 44, 62, 32, 21, 29, 67, 38, 25, 30, 50, 42, 59, 41, 40, 37, 59, 48, 39, 47, 69, 51, 38, 31, 68, 51, 28, 49, 51, 57, 39, 63, 37, 54, 49, 41, 65, 20, 43, 29, 25, 45, 70, 51, 28, 58, 47, 69, 32, 28, 24, 30, 38, 29, 47, 40, 61, 45, 67, 42, 56, 49, 65, 68, 58, 32, 30, 47]

# %%
# Crear un DataFrame con las edades
df = pd.DataFrame({'Edad': edades})
df
# Out:
#     Edad
# 0     65
# 1     48
# 2     47
# 3     43
# 4     62
# ..   ...
# 95    68
# 96    58
# 97    32
# 98    30
# 99    47
#
# [100 rows x 1 columns]

# %%
# Calcular el número de intervalos utilizando la regla de Sturges
n = len(edades)
K = int(1 + math.log2(n))

print("Valor de n = ", n, "\nNúmero de intervalos = ", K)
# Crear la tabla de frecuencia
# Out:
# Valor de n =  100
# Número de intervalos =  7

# %%
 #Crear la tabla de frecuencia

tabla_frecuencia = pd.cut(df['Edad'], bins=K, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (25.429, 32.857]    19
# 1  (40.286, 47.714]    18
# 2  (32.857, 40.286]    15
# 3  (47.714, 55.143]    15
# 4    (62.571, 70.0]    14
# 5  (55.143, 62.571]    11
# 6  (17.947, 25.429]     8

# %%
# Ordenar la tabla de frecuencia por el intervalo
tabla_frecuencia = tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 6  (17.947, 25.429]     8
# 0  (25.429, 32.857]    19
# 2  (32.857, 40.286]    15
# 1  (40.286, 47.714]    18
# 3  (47.714, 55.143]    15
# 5  (55.143, 62.571]    11
# 4    (62.571, 70.0]    14

# %%
# Generar columnas siguientes
tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec'] / n
tabla_frecuencia['Frec Porc'] = tabla_frecuencia['Frec'] / n * 100
tabla_frecuencia['Frec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac'] = tabla_frecuencia['Frec Porc'].cumsum()

# Mostrar la tabla de frecuencia
print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Rel Ac  Frec Porc Ac
# 6  (17.947, 25.429]     8      0.08        8.0         0.08           8.0
# 0  (25.429, 32.857]    19      0.19       19.0         0.27          27.0
# 2  (32.857, 40.286]    15      0.15       15.0         0.42          42.0
# 1  (40.286, 47.714]    18      0.18       18.0         0.60          60.0
# 3  (47.714, 55.143]    15      0.15       15.0         0.75          75.0
# 5  (55.143, 62.571]    11      0.11       11.0         0.86          86.0
# 4    (62.571, 70.0]    14      0.14       14.0         1.00         100.0

# %%
import matplotlib.pyplot as plt

plt.hist(edades, alpha = 0.5)
plt.title("Histograma de edades basado en la función de matplotlib con valores estándar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la función de matplotlib con valores estándar')

# %%
# Crear un histograma basado en la tabla de frecuencia
plt.hist(df['Edad'], bins=K, alpha=0.5)
plt.title('Histograma de edades basado en la regla de Sturges')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
